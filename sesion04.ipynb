# %% [markdown]
# # Sesión 4
#
# - Mi primer notebook
# - Imprimir árbol
# - Crear Markdown
# - Subir a mi repositorio de GITHUB
# - DIbujar un emoji 😃
#
# ![Horikita](https://github.com/Juamjocal27/psg-example/blob/main/Horikita.jpg?raw=true)

# %%
# CODE 01
print("Hola mundo desde Notebook!")
# Out:
# Hola mundo desde Notebook!

# %%
print("   *")
print("  ***")
print(" *****")
print("*******")
print("  | |   ")
# Out:
#    *
#   ***
#  *****
# *******
#   | |
